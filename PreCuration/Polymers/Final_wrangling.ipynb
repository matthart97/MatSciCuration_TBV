# %%
import pandas as pd

import pandas as pd
import os


PATH = os.getcwd()
data_path = PATH +"Polymer_lake/"

# Read the CSV file into a DataFrame
df = pd.read_csv('Khazana.csv')

# Rename the 'smiles' column to 'PSMILES'
df.rename(columns={'smiles': 'PSMILES'}, inplace=True)

# Pivot the DataFrame to create a sparse matrix
sparse_matrix = df.pivot( index = 'PSMILES',columns=['property', ], values='value')


sparse_matrix.reset_index(inplace=True)
# Write the sparse matrix to a new CSV file
sparse_matrix.to_csv('Polymer_lake/KhazanaMatrix.csv',index=False)

# %%
sparse_matrix
# Out:
# property                                            PSMILES  Eat  Eea  Egb  \
# 0         C(=O)([*])C1=CC=C(C=C1)C(=O)OC1=CC=C(C=C1)C2(C...  NaN  NaN  NaN
# 1         C(=O)([*])C1=CC=C(C=C1)S(=O)(=O)C1=CC=C(C=C1)C...  NaN  NaN  NaN
# 2         C(=O)([*])C1=CC=C(C=C1)S(=O)(=O)C1=CC=C(C=C1)C...  NaN  NaN  NaN
# 3         C13C(C=[*])OC(C=[*])C1C(=O)N(C2=CC=C(C(F)(F)F)...  NaN  NaN  NaN
# 4         C13C(C=[*])OC(C=[*])C1C(=O)N(C2=CC=CC(C(F)(F)F...  NaN  NaN  NaN
# ...                                                     ...  ...  ...  ...
# 3650      [*]c8ccc(C7(c4ccc(n3c(=O)c2cc1c(=O)n([*])c(=O)...  NaN  NaN  NaN
# 3651      [*]c8ccc(C7(c5ccc(n4c(=O)c3ccc(Oc2ccc1c(=O)n([...  NaN  NaN  NaN
# 3652      [*]c9ccc(C8(c5ccc(n4c(=O)c3ccc(C(=O)c2ccc1c(=O...  NaN  NaN  NaN
# 3653      [*]n1nc(-n2c(=O)c3cc4c(=O)n([*])c(=O)c4cc3c2=O...  NaN  NaN  NaN
# 3654      c1([*])cc(c2cc1)N=C(N2(C(c2(c3))=O))c1c2c(c4(c...  NaN  NaN  NaN
#
# property     Egc  Ei  Xc  eps  nc
# 0         3.8358 NaN NaN  NaN NaN
# 1         3.2146 NaN NaN  NaN NaN
# 2         3.3925 NaN NaN  NaN NaN
# 3         5.3690 NaN NaN  NaN NaN
# 4         5.0879 NaN NaN  NaN NaN
# ...          ...  ..  ..  ...  ..
# 3650      2.1924 NaN NaN  NaN NaN
# 3651      3.3847 NaN NaN  NaN NaN
# 3652      2.4589 NaN NaN  NaN NaN
# 3653      2.9967 NaN NaN  NaN NaN
# 3654      2.3866 NaN NaN  NaN NaN
#
# [3655 rows x 9 columns]

# %%
df1 = pd.read_csv("/home/matt/Proj/MatSciCuration_TBV/PreCuration/Polymers/Polymer_lake/highTdata.csv")
df1 = df1.rename(columns = {"smis.uni":"PSMILES"})
df0 = pd.read_csv('Polymer_lake/KhazanaMatrix.csv')

# %%
df1 = df1.drop(['Unnamed: 0'],axis=1)

# %%
df0.reset_index(inplace=True)

# %%
DF = df0.merge(df1, on='PSMILES', how = 'outer')

# %%
DF.to_csv("/home/matt/Proj/MatSciCuration_TBV/PreCuration/Polymers/Polymer_lake/TandKhaz.csv",index = False)

# %% [markdown]
# # merge this data with the CROW data

# %%
import pandas as pd
import json

# Read the JSON file
with open('/home/matt/Proj/MatSciCuration_TBV/PreCuration/Polymers/Polymer_lake/CROW_PSMILES.json', 'r') as f:
    json_data = json.load(f)

# %%
# Convert the JSON data to a pandas DataFrame
json_df = pd.json_normalize(json_data)

# %%
json_df
# Out:
#                       polymer name  \
# 0                 Poly(acrylamide)
# 1     Poly(N-isopropyl acrylamide)
# 2         Poly(N-octyl acrylamide)
# 3    Poly(N-tert-butyl acrylamide)
# 4         Poly(N-phenylacrylamide)
# ..                             ...
# 416    Poly(butyl vinyl thioether)
# 417    Poly(ethyl vinyl thioether)
# 418   Poly(methyl vinyl thioether)
# 419     Poly(vinyl phenyl sulfide)
# 420   Poly(propyl vinyl thioether)
#
#                       NAMES AND IDENTIFIERS OF POLYMER  \
# 0    [{'POLYMER CLASS': 'Polyacrylamide'}, {'COMMON...
# 1    [{'POLYMER CLASS': 'Polyacrylamide'}, {'COMMON...
# 2    [{'POLYMER CLASS': 'Polyacrylamide'}, {'COMMON...
# 3    [{'POLYMER CLASS': 'Polyacrylamide'}, {'COMMON...
# 4    [{'POLYMER CLASS': 'Polyacrylamide'}, {'COMMON...
# ..                                                 ...
# 416  [{'POLYMER CLASS': 'Polyvinylsulfide'}, {'COMM...
# 417  [{'POLYMER CLASS': 'Polyvinylsulfide'}, {'COMM...
# 418  [{'POLYMER CLASS': 'Polyvinylsulfide'}, {'COMM...
# 419  [{'POLYMER CLASS': 'Polyvinylsulfide'}, {'COMM...
# 420  [{'POLYMER CLASS': 'Polyvinylsulfide'}, {'COMM...
#
#                              IDENTIFIERS OF MONOMER(S)  \
# 0    [{'CAS #': '79-06-1'}, {'COMMON NAMES': 'Acryl...
# 1    [{'CAS #': '2210-25-5'}, {'COMMON NAMES': 'N-I...
# 2    [{'CAS #': '10124-68-2'}, {'COMMON NAMES': ''}...
# 3    [{'CAS #': '107-58-4'}, {'COMMON NAMES': 'N-te...
# 4    [{'CAS #': '2210-24-4'}, {'COMMON NAMES': 'N-P...
# ..                                                 ...
# 416  [{'CAS #': '4789-70-2'}, {'COMMON NAMES': 'But...
# 417  [{'CAS #': '627-50-9'}, {'COMMON NAMES': 'Ethy...
# 418  [{'CAS #': '1822-74-8'}, {'COMMON NAMES': 'Met...
# 419  [{'CAS #': '1822-73-7'}, {'COMMON NAMES': 'Vin...
# 420  [{'CAS #': '16330-21-5'}, {'COMMON NAMES': 'Pr...
#
#     Thermo-Physical Properties: Experimental / Literature Data  \
# 0    [{'PROPERTY': 'UNIT', 'VALUE / RANGE': 'PREFER...
# 1    [{'PROPERTY': 'UNIT', 'VALUE / RANGE': 'PREFER...
# 2    [{'PROPERTY': 'UNIT', 'VALUE / RANGE': 'PREFER...
# 3    [{'PROPERTY': 'UNIT', 'VALUE / RANGE': 'PREFER...
# 4    [{'PROPERTY': 'UNIT', 'VALUE / RANGE': 'PREFER...
# ..                                                 ...
# 416  [{'PROPERTY': 'UNIT', 'VALUE / RANGE': 'PREFER...
# 417  [{'PROPERTY': 'UNIT', 'VALUE / RANGE': 'PREFER...
# 418  [{'PROPERTY': 'UNIT', 'VALUE / RANGE': 'PREFER...
# 419  [{'PROPERTY': 'UNIT', 'VALUE / RANGE': 'PREFER...
# 420  [{'PROPERTY': 'UNIT', 'VALUE / RANGE': 'PREFER...
#
#            Thermo-Physical Properties: Calculated Data
# 0    [{'PROPERTY': 'UNIT', 'VALUE / RANGE': 'PREFER...
# 1    [{'PROPERTY': 'UNIT', 'VALUE / RANGE': 'PREFER...
# 2    [{'PROPERTY': 'UNIT', 'VALUE / RANGE': 'PREFER...
# 3    [{'PROPERTY': 'UNIT', 'VALUE / RANGE': 'PREFER...
# 4    [{'PROPERTY': 'UNIT', 'VALUE / RANGE': 'PREFER...
# ..                                                 ...
# 416  [{'PROPERTY': 'UNIT', 'VALUE / RANGE': 'PREFER...
# 417  [{'PROPERTY': 'UNIT', 'VALUE / RANGE': 'PREFER...
# 418  [{'PROPERTY': 'UNIT', 'VALUE / RANGE': 'PREFER...
# 419  [{'PROPERTY': 'UNIT', 'VALUE / RANGE': 'PREFER...
# 420  [{'PROPERTY': 'UNIT', 'VALUE / RANGE': 'PREFER...
#
# [421 rows x 5 columns]

# %%
json_df["NAMES AND IDENTIFIERS OF POLYMER"][0][5]['PSMILES']
# Out:
# '*CC*(C(=O)N)'

# %%
psmiles  = [json_df["NAMES AND IDENTIFIERS OF POLYMER"][i][5]['PSMILES'] for i in range(0,len(json_df))]

# %%
json_df['PSMILES'] = psmiles

# %%
# Merge the DataFrames on the 'SMILES' column
merged_df = json_df.merge(DF, on='PSMILES', how='outer')

# %%
merged_df.to_csv("PolymerData_uncurated.csv",index=False)
