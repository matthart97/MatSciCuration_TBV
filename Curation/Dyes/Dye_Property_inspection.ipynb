# %%
import pandas as pd 
import numpy as np 
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# get the peropteis that we need
df = pd.read_csv("/home/matt/Proj/MatSciCuration_TBV/Data/Dyes/Dyes_Matched.csv")

# %%
ç
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 ç
#
# NameError: name 'ç' is not defined

# %%
df.columns
# Out:
# Index(['SMILES', 'Tag', 'Solvent', 'Absorption max (nm)', 'Emission max (nm)',
#        'Lifetime (ns)', 'Quantum yield', 'log(e/mol-1 dm3 cm-1)',
#        'abs FWHM (cm-1)', 'emi FWHM (cm-1)', 'abs FWHM (nm)', 'emi FWHM (nm)',
#        'Molecular weight (g mol-1)', 'Reference', 'identifier', 'vie', 'aie',
#        'vea', 'aea', 'hl', 's0s1', 's0t1', 'hr', 'cr2', 'cr1', 'er', 'ar1',
#        'ar2', 'lumo', 'homo'],
#       dtype='object')

# %%
props= ['Absorption max (nm)', 'Emission max (nm)',
       'Lifetime (ns)', 'Quantum yield', 'log(e/mol-1 dm3 cm-1)',
       'abs FWHM (cm-1)', 'emi FWHM (cm-1)', 'abs FWHM (nm)', 'emi FWHM (nm)',
       'Molecular weight (g mol-1)', 'vie', 'aie',
       'vea', 'aea', 'hl', 's0s1', 's0t1', 'hr', 'cr2', 'cr1', 'er', 'ar1',
       'ar2', 'lumo', 'homo']

# %%
for prop in props:
    plt.figure()
    ax = sns.histplot(df[prop], kde=True, bins=20, color='skyblue', edgecolor='black', alpha=0.7)
    plt.xlabel('Value')
    plt.title(prop)
    plt.show()
# Out:
# ---------------------------------------------------------------------------
# OptionError                               Traceback (most recent call last)
# Cell In[7], line 3
#       1 for prop in props:
#       2     plt.figure()
# ----> 3     ax = sns.histplot(df[prop], kde=True, bins=20, color='skyblue', edgecolor='black', alpha=0.7)
#       4     plt.xlabel('Value')
#       5     plt.title(prop)
#
# File ~/anaconda3/envs/RDKit/lib/python3.10/site-packages/seaborn/distributions.py:1432, in histplot(data, x, y, hue, weights, stat, bins, binwidth, binrange, discrete, cumulative, common_bins, common_norm, multiple, element, fill, shrink, kde, kde_kws, line_kws, thresh, pthresh, pmax, cbar, cbar_ax, cbar_kws, palette, hue_order, hue_norm, color, log_scale, legend, ax, **kwargs)
#    1421 estimate_kws = dict(
#    1422     stat=stat,
#    1423     bins=bins,
#    (...)
#    1427     cumulative=cumulative,
#    1428 )
#    1430 if p.univariate:
# ...

# %% [markdown]
# The following properties contain datapoints that may be considered unlikely for organic molecuels:
#
# - emission Full Width Half Maximum
# - Lifetime (ns)
# - absorption FWHM
#
#
# Here, the datapoints are few enough that we can inspect them manually

# %%
df[df['Lifetime (ns)']>300]
# Out:
#                                                   SMILES      Tag  Solvent  \
# 17                            c1cc2ccc3cccc4ccc(c1)c2c34    561.0  CCCCCCC
# 25361                  O=C(O)CCCc1ccc2ccc3cccc4ccc1c2c34   8391.0       CO
# 27708                O=C(O)CCCc1cc2ccc3cccc4ccc(c1)c2c34   8375.0       CO
# 31252  CC1(C)[C@@H]2[C@@H]1[C@]1(c3ccccc3)N=NC2(c2ccc...  12393.0     CC#N
# 31351                             C1C[C@H]2CC[C@@H]1N=N2  12377.0     CC#N
#
#        Absorption max (nm)  Emission max (nm)  Lifetime (ns)  Quantum yield  \
# 17                   334.0              373.0          462.0           0.53
# 25361                375.0              375.0          460.0           0.68
# 27708                374.0              374.0          622.0           0.52
# 31252                  NaN                NaN          402.0           0.08
# 31351                  NaN                NaN          434.0           0.39
#
# ...

# %%
df[df['emi FWHM (cm -1)']>300]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 df[df['emi FWHM (cm -1)']>300]
#
# NameError: name 'df' is not defined
